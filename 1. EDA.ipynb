# %% [markdown]
# ## EDA about musicNet data

# %%
dataset = 'musicnet/EDA/musicnet_metadata.csv'

# %%
import pandas as pd 
df = pd.read_csv(dataset)

# %%
df
# Out:
#        id   composer                         composition  \
# 0    1727   Schubert            Piano Quintet in A major
# 1    1728   Schubert            Piano Quintet in A major
# 2    1729   Schubert            Piano Quintet in A major
# 3    1730   Schubert            Piano Quintet in A major
# 4    1733   Schubert             Piano Sonata in A major
# 5    1734   Schubert             Piano Sonata in A major
# 6    1735   Schubert             Piano Sonata in A major
# 7    1739   Schubert          Piano Trio in B-flat major
# 8    1742   Schubert           String Quintet in C major
# 9    1749   Schubert             Piano Sonata in A minor
# 10   1750   Schubert             Piano Sonata in A minor
# 11   1751   Schubert             Piano Sonata in A minor
# 12   1752   Schubert             Piano Sonata in A minor
# 13   1755   Schubert             Piano Sonata in A minor
# 14   1756   Schubert             Piano Sonata in A minor
# ...

# %%
#df.sum(axis = 0, skipna = True)  #skip the NaN values

#sum() function to find the sum of all the values over the column axis.
#df.sum(axis = 1, skipna = True) 

#df['composition'].value_count()
#pd.value_counts(df.values.flatten())

# %%
df.count()
# Out:
# id              330
# composer        330
# composition     330
# movement        330
# ensemble        330
# source          330
# transcriber     330
# catalog_name    330
# seconds         330
# dtype: int64

# %%
df['composer'].value_counts().plot(kind='bar') #barh for horizontal bar graph

# %%
df['ensemble'].value_counts().plot(kind='barh')

# %%
df['composition'].value_counts()[:20].plot(kind='barh')

# %%
#df1 = df.groupby('composition')['id'].nunique()
df.drop_duplicates().composition.value_counts()
# Out:
# Piano Sonata No 17 in D minor                        6
# Piano Sonata No 4 in E-flat major                    6
# Cello Suite 4                                        6
# Piano Sonata No 3 in C major                         6
# Piano Sonata in A minor                              6
# Cello Suite 3                                        6
# String Quartet No 19 in C major                      6
# Piano Sonata No 14 in C-sharp minor                  5
# Violin Sonata No 8 in G major                        5
# Piano Sonata No 2 in A major                         5
# String Quartet No 10 in E-flat major                 5
# Piano Sonata in A major                              4
# Piano Sonata No 15 in D major                        4
# Piano Quartet No 2 in G minor                        4
# Piano Quartet No 1 in G minor                        4
# Piano Quintet in A major                             4
# 4 Impromptus                                         4
# ...
